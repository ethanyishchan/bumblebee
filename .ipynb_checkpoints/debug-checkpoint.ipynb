# %%
import pickle
output = open('output_memo.txt', 'rb')
memo = pickle.load(output)

# %%
memo
# Out:
# {'yellow': [('00:09:27.570554',
#    '00:09:28.160998',
#    0.2296171111111111,
#    'lego_movie'),
#   ('00:01:43.590668', '00:01:44.164001', 0.2229631111111111, 'lego_movie'),
#   ('00:10:08.654750', '00:10:09.129000', 0.088921875, 'fantastic_mr_fox')],
#  'four': [('00:29:58.916666', '00:30:00.014999', 0.732222, 'boyhood'),
#   ('00:11:23.267500', '00:11:24.010000', 0.556875, 'whiplash'),
#   ('00:37:53.036800', '00:37:53.942400', 0.5433600000000001, 'boyhood'),
#   ('00:55:46.948250', '00:55:47.611000', 0.4970625, 'boyhood'),
#   ('00:11:30.601500', '00:11:31.523000', 0.46075, 'whiplash'),
#   ('00:11:18.002000', '00:11:18.884000', 0.441, 'whiplash'),
#   ('00:11:01.682000', '00:11:02.524000', 0.421, 'whiplash'),
#   ('01:29:46.701000', '01:29:47.227500', 0.394875, 'dead_poets_society'),
#   ('00:42:08.756666', '00:42:09.209999', 0.3777776666666666, 'interstellar'),
#   ('00:11:06.665500', '00:11:07.331000', 0.33275, 'whiplash'),
#   ('00:03:01.211333',
#    '00:03:01.636555',
# ...

# %%
available_words = open("words.txt")
for w in memo.keys():
    available_words.write(w)
    available_words.write("\n")
available_words.close()

# %%
from parse_and_dump import init

# %%
init('input_videos.txt')
# Out:
# initializing..
# /Users/yishh/Documents/VuzeDownloads/interstellar/interstellar.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/man_of_steel/man_of_steel.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/the_dark_knight/the_dark_knight.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/fantastic_mr_fox/fantastic_mr_fox.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/whiplash/whiplash.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/the_prestige/the_prestige.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/dallas_buyers_club/dallas_buyers_club.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/lego_movie/lego_movie.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/boyhood/boyhood.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/dead_poets_society/dead_poets_society.mp4 ----- done -----
# /Users/yishh/Documents/VuzeDownloads/pocahontas/pocahontas.mp4 ----- done -----
# removed old output
# ...
